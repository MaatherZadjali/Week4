# %% [markdown]
# #### My Jupyter Notebook on IBM Watson Studio

# %%
** Maather **
# Out:
#   Input In [3]
#     ** Maather **
#     ^
# SyntaxError: invalid syntax

# %%
<sub>My current position is 'Fraud analyst'</sub>
# Out:
#   Input In [2]
#     <sub>My current position is 'Fraud analyst'</sub>
#     ^
# SyntaxError: invalid syntax

# %%
* *I am intrested in data-science because I love working with data and getting to conclusions* *
# Out:
#   Input In [4]
#     * *I am intrested in data-science because I love working with data and getting to conclusions* *
#       ^
# SyntaxError: invalid syntax

# %%
### My code below is the addition of 3 numbers

# %%
Print(22+22+22)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 Print(22+22+22)
#
# NameError: name 'Print' is not defined

# %%
>This task was
-Easy
-Clear
-Simple


This site was built using [GitHub Pages](https://pages.github.com/).
![This is an image](https://myoctocat.com/assets/images/base-octocat.svg)
# Out:
#   Input In [8]
#     >This task was
#     ^
# SyntaxError: invalid syntax
